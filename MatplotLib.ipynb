# %% [markdown]
# <a href="https://colab.research.google.com/github/aryaparasharmrt/arya/blob/master/MatplotLib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
dir_path='/content/drive/MyDrive/CSV'
df = pd.read_csv(dir_path + '/pp-2018.csv', names = ["TID","Price","Sale Date", "Postcode",
                                    "Property Type","New Build","Tenure",
                                    "PAON","SAON","Street","Locality",
                                    "Town/City","District","County",
                                    "PPD Category","Record Status"],
                            parse_dates= ["Sale Date"])

# %%
df
# Out:
#                                             TID  ...  Record Status
# 0        {666758D7-43A9-3363-E053-6B04A8C0D74E}  ...              A
# 1        {666758D7-43AA-3363-E053-6B04A8C0D74E}  ...              A
# 2        {666758D7-43AD-3363-E053-6B04A8C0D74E}  ...              A
# 3        {666758D7-43B0-3363-E053-6B04A8C0D74E}  ...              A
# 4        {666758D7-43B3-3363-E053-6B04A8C0D74E}  ...              A
# ...                                         ...  ...            ...
# 1024427  {80E1AA98-9F64-7BF8-E053-6C04A8C00BF2}  ...              A
# 1024428  {80E1AA98-9F67-7BF8-E053-6C04A8C00BF2}  ...              A
# 1024429  {80E1AA98-9F69-7BF8-E053-6C04A8C00BF2}  ...              A
# 1024430  {80E1AA98-9F6A-7BF8-E053-6C04A8C00BF2}  ...              A
# 1024431  {80E1AA98-9F6B-7BF8-E053-6C04A8C00BF2}  ...              A
#
# [1024432 rows x 16 columns]

# %%
df['Sale Date']
# Out:
# 0         2018-01-25
# 1         2018-01-23
# 2         2018-01-19
# 3         2018-01-22
# 4         2018-01-19
#              ...
# 1024427   2018-12-10
# 1024428   2018-12-20
# 1024429   2018-12-14
# 1024430   2018-12-07
# 1024431   2018-12-11
# Name: Sale Date, Length: 1024432, dtype: datetime64[ns]

# %%
df["Month"]=df["Sale Date"].apply(lambda x: x.strftime("%Y-%m-%d")[:7])

# %%
df
# Out:
#                                             TID   Price  ... Record Status    Month
# 0        {666758D7-43A9-3363-E053-6B04A8C0D74E}  405000  ...             A  2018-01
# 1        {666758D7-43AA-3363-E053-6B04A8C0D74E}  315000  ...             A  2018-01
# 2        {666758D7-43AD-3363-E053-6B04A8C0D74E}  165000  ...             A  2018-01
# 3        {666758D7-43B0-3363-E053-6B04A8C0D74E}  370000  ...             A  2018-01
# 4        {666758D7-43B3-3363-E053-6B04A8C0D74E}  320000  ...             A  2018-01
# ...                                         ...     ...  ...           ...      ...
# 1024427  {80E1AA98-9F64-7BF8-E053-6C04A8C00BF2}  382500  ...             A  2018-12
# 1024428  {80E1AA98-9F67-7BF8-E053-6C04A8C00BF2}  394000  ...             A  2018-12
# 1024429  {80E1AA98-9F69-7BF8-E053-6C04A8C00BF2}  350000  ...             A  2018-12
# 1024430  {80E1AA98-9F6A-7BF8-E053-6C04A8C00BF2}  346000  ...             A  2018-12
# ...

# %%
 monthly_sales_vol=df["Month"].value_counts()

# %%
 monthly_sales_vol.sort_index(inplace=True)

# %%
 monthly_sales_vol
# Out:
# 2018-01     70031
# 2018-02     71579
# 2018-03     84172
# 2018-04     72322
# 2018-05     81458
# 2018-06     95790
# 2018-07     88674
# 2018-08    101485
# 2018-09     82845
# 2018-10     92577
# 2018-11     98532
# 2018-12     84967
# Name: Month, dtype: int64

# %%
df.shape
# Out:
# (1024432, 17)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.rcParams['figure.figsize']=(10, 5)

# %%
plt.plot(monthly_sales_vol)

# %%
plt.plot(monthly_sales_vol)
plt.title("Monthly Sales in Year 2018")
plt.ylabel("Monthly Sales")
plt.xlabel("Months")
# Out:
# Text(0.5, 0, 'Months')

# %%
df.groupby("Month")['TID'].count().reset_index().rename(columns={'Sale Date':'Date'})
# Out:
#       Month     TID
# 0   2018-01   70031
# 1   2018-02   71579
# 2   2018-03   84172
# 3   2018-04   72322
# 4   2018-05   81458
# 5   2018-06   95790
# 6   2018-07   88674
# 7   2018-08  101485
# 8   2018-09   82845
# 9   2018-10   92577
# 10  2018-11   98532
# 11  2018-12   84967

# %%
df=df[df["Sale Date"].dt.month==7]
df
# Out:
#                                             TID   Price  ... Record Status    Month
# 835      {79A74E21-D135-1289-E053-6B04A8C01627}   84000  ...             A  2018-07
# 1044     {773788C2-6D59-2CE4-E053-6C04A8C05E57}  228000  ...             A  2018-07
# 1055     {773788C2-6D60-2CE4-E053-6C04A8C05E57}  330000  ...             A  2018-07
# 1123     {79A74E21-B602-1289-E053-6B04A8C01627}  140000  ...             A  2018-07
# 1214     {79A74E21-BC74-1289-E053-6B04A8C01627}  375000  ...             A  2018-07
# ...                                         ...     ...  ...           ...      ...
# 1024095  {80E1AA98-B375-7BF8-E053-6C04A8C00BF2}  483000  ...             A  2018-07
# 1024231  {80E1AA98-BA30-7BF8-E053-6C04A8C00BF2}  219000  ...             A  2018-07
# 1024234  {80E1AA98-BA34-7BF8-E053-6C04A8C00BF2}  332500  ...             A  2018-07
# 1024267  {80E1AA98-9136-7BF8-E053-6C04A8C00BF2}  637500  ...             A  2018-07
# ...

# %%
specific_monthly_sale=df['Sale Date'].value_counts()
specific_monthly_sale.sort_index(inplace=True)

# %%
specific_monthly_sale
# Out:
# 2018-07-01       30
# 2018-07-02     3213
# 2018-07-03     2048
# 2018-07-04     2270
# 2018-07-05     2640
# 2018-07-06     8832
# 2018-07-07       25
# 2018-07-08       13
# 2018-07-09     2419
# 2018-07-10     2146
# 2018-07-11     2335
# 2018-07-12     3816
# 2018-07-13     6949
# 2018-07-14       31
# 2018-07-15       24
# 2018-07-16     3115
# 2018-07-17     2133
# 2018-07-18     2617
# 2018-07-19     2768
# 2018-07-20     9182
# 2018-07-21       25
# 2018-07-22       17
# 2018-07-23     2958
# 2018-07-24     2296
# 2018-07-25     2904
# 2018-07-26     3230
# 2018-07-27    11579
# 2018-07-28       33
# 2018-07-29       28
# 2018-07-30     3601
# 2018-07-31     5397
# Name: Sale Date, dtype: int64

# %%
specific_monthly_sale.plot()
plt.title("Sales in Month of July")
plt.xlabel("Date")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
daily_sales=df.groupby(['Sale Date','Property Type'])["TID"].count().unstack()

# %%
daily_sales.columns
# Out:
# Index(['D', 'F', 'O', 'S', 'T'], dtype='object', name='Property Type')

# %%
daily_sales
# Out:
# Property Type     D     F    O     S     T
# Sale Date
# 2018-07-01        4     2   12     7     5
# 2018-07-02      705   564  282   782   880
# 2018-07-03      443   426  220   436   523
# 2018-07-04      529   401  206   528   606
# 2018-07-05      623   453  282   614   668
# 2018-07-06     1955  1662  432  2422  2361
# 2018-07-07        7     6    7     2     3
# 2018-07-08        2     4    2     1     4
# 2018-07-09      498   447  160   638   676
# 2018-07-10      539   405  161   498   543
# 2018-07-11      544   416  170   633   572
# 2018-07-12      916   641  248  1000  1011
# 2018-07-13     1489  1211  388  1904  1957
# 2018-07-14        4     6    6     9     6
# 2018-07-15        4     3    4     5     8
# 2018-07-16      676   582  232   828   797
# 2018-07-17      526   379  200   499   529
# 2018-07-18      602   537  179   662   637
# 2018-07-19      717   462  197   699   693
# 2018-07-20     2017  1476  380  2626  2683
# ...

# %%
daily_sales.plot()

# %%
plt.rcParams['figure.figsize']=(10,5)
daily_sales.plot(kind='bar')

# %%
sales_type=df['Property Type'].value_counts()

# %%
sales_type
# Out:
# T    23630
# S    23501
# D    20406
# F    15545
# O     5592
# Name: Property Type, dtype: int64

# %%
sales_type.plot(kind='box')
plt.ylabel('Number of Sales')
plt.xlabel('Proper Type')
plt.title('Total Sales of Each Property Type')
# Out:
# Text(0.5, 1.0, 'Total Sales of Each Property Type')

# %%
mean_price=df.groupby(['Property Type'])['Price'].mean()

# %%
mean_price
# Out:
# Property Type
# D    4.208703e+05
# F    3.065781e+05
# O    1.090097e+06
# S    2.603536e+05
# T    2.488554e+05
# Name: Price, dtype: float64

# %%
dfa=mean_price.plot.bar(figsize=(10,5),fontsize=10)
dfa.set_title('Average of Each Property Type',fontsize=15)
dfa.set_xlabel('Property Type',fontsize=10)
dfa.set_ylabel('Counts Of Each Property Type',fontsize=10)
# Out:
# Text(0, 0.5, 'Counts Of Each Property Type')

# %%
df.groupby(['Sale Date','Property Type'])['Price'].mean().unstack().plot(kind='bar')

# %%
df.groupby(['Sale Date','Property Type'])['Price'].mean().unstack()
# Out:
# Property Type              D              F  ...              S              T
# Sale Date                                    ...
# 2018-07-01     540000.000000  109000.000000  ...  172571.428571  217400.000000
# 2018-07-02     445515.668085  350084.714539  ...  270838.773657  255916.592045
# 2018-07-03     447700.440181  373247.507042  ...  247046.855505  269273.124283
# 2018-07-04     438009.792060  334057.576060  ...  280296.412879  242835.457096
# 2018-07-05     458506.836276  333304.015453  ...  269661.234528  245529.871257
# 2018-07-06     388179.344246  280558.135379  ...  248347.932700  223573.152478
# 2018-07-07     383420.714286  267990.833333  ...  157500.000000  490333.333333
# 2018-07-08     213500.000000  147123.750000  ...  245000.000000  116250.000000
# 2018-07-09     401749.847390  301908.429530  ...  265197.501567  291172.751479
# 2018-07-10     474461.918367  292347.762963  ...  270308.014056  266264.843462
# ...

# %%
df2=pd.read_csv(dir_path+'/Speed Dating Data.csv',encoding='unicode_escape')

# %%
df2
# Out:
#       iid    id  gender  idg  ...  sinc5_3  intel5_3  fun5_3  amb5_3
# 0       1   1.0       0    1  ...      NaN       NaN     NaN     NaN
# 1       1   1.0       0    1  ...      NaN       NaN     NaN     NaN
# 2       1   1.0       0    1  ...      NaN       NaN     NaN     NaN
# 3       1   1.0       0    1  ...      NaN       NaN     NaN     NaN
# 4       1   1.0       0    1  ...      NaN       NaN     NaN     NaN
# ...   ...   ...     ...  ...  ...      ...       ...     ...     ...
# 8373  552  22.0       1   44  ...      5.0       9.0     5.0     6.0
# 8374  552  22.0       1   44  ...      5.0       9.0     5.0     6.0
# 8375  552  22.0       1   44  ...      5.0       9.0     5.0     6.0
# 8376  552  22.0       1   44  ...      5.0       9.0     5.0     6.0
# 8377  552   NaN       1   44  ...      5.0       9.0     5.0     6.0
#
# [8378 rows x 195 columns]

# %%
df2.columns.values
# Out:
# array(['iid', 'id', 'gender', 'idg', 'condtn', 'wave', 'round',
#        'position', 'positin1', 'order', 'partner', 'pid', 'match',
#        'int_corr', 'samerace', 'age_o', 'race_o', 'pf_o_att', 'pf_o_sin',
#        'pf_o_int', 'pf_o_fun', 'pf_o_amb', 'pf_o_sha', 'dec_o', 'attr_o',
#        'sinc_o', 'intel_o', 'fun_o', 'amb_o', 'shar_o', 'like_o',
#        'prob_o', 'met_o', 'age', 'field', 'field_cd', 'undergra',
#        'mn_sat', 'tuition', 'race', 'imprace', 'imprelig', 'from',
#        'zipcode', 'income', 'goal', 'date', 'go_out', 'career',
#        'career_c', 'sports', 'tvsports', 'exercise', 'dining', 'museums',
#        'art', 'hiking', 'gaming', 'clubbing', 'reading', 'tv', 'theater',
#        'movies', 'concerts', 'music', 'shopping', 'yoga', 'exphappy',
#        'expnum', 'attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1',
#        'shar1_1', 'attr4_1', 'sinc4_1', 'intel4_1', 'fun4_1', 'amb4_1',
# ...

# %%
age =df2[~df2['age'].isna()]['age']

# %%
age
# Out:
# 0       21.0
# 1       21.0
# 2       21.0
# 3       21.0
# 4       21.0
#         ...
# 8373    25.0
# 8374    25.0
# 8375    25.0
# 8376    25.0
# 8377    25.0
# Name: age, Length: 8283, dtype: float64

# %%
age.values
# Out:
# array([21., 21., 21., ..., 25., 25., 25.])

# %%
age.shape
# Out:
# (8283,)

# %%
age.values[::1]
# Out:
# array([21., 21., 21., ..., 25., 25., 25.])

# %%
plt.hist(age.values,color='blue')
# Out:
# (array([ 376., 3249., 3263.,  909.,  418.,   42.,   20.,    0.,    0.,
#            6.]),
#  array([18. , 21.7, 25.4, 29.1, 32.8, 36.5, 40.2, 43.9, 47.6, 51.3, 55. ]),
#  <a list of 10 Patch objects>)

# %%
gfg=df2['age'].value_counts()

# %%
plt.hist(gfg, color='red')
# Out:
# (array([10.,  4.,  1.,  0.,  0.,  2.,  1.,  2.,  3.,  1.]),
#  array([   5. ,  110.4,  215.8,  321.2,  426.6,  532. ,  637.4,  742.8,
#          848.2,  953.6, 1059. ]),
#  <a list of 10 Patch objects>)

# %%
import seaborn as sns

# %%
sns.distplot(age, hist=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# x=[1,2,3,4,5,6,7,8]
# y=[2,3,4,5,6,7,8,9]
x=[9,8,7,6,5,4,3,2,1]
y=[1,2,3,4,0,6,7,8,9]

# %%
df3=pd.DataFrame(data={'x':x,'y':y})

# %%
df3
# Out:
#    x  y
# 0  9  1
# 1  8  2
# 2  7  3
# 3  6  4
# 4  5  0
# 5  4  6
# 6  3  7
# 7  2  8
# 8  1  9

# %%
sns.lmplot(x='x',y='y',data=df3)

# %%
df3.corr()
# Out:
#           x         y
# x  1.000000 -0.854242
# y -0.854242  1.000000

# %%
df2
# Out:
#       iid    id  gender  idg  ...  sinc5_3  intel5_3  fun5_3  amb5_3
# 0       1   1.0       0    1  ...      NaN       NaN     NaN     NaN
# 1       1   1.0       0    1  ...      NaN       NaN     NaN     NaN
# 2       1   1.0       0    1  ...      NaN       NaN     NaN     NaN
# 3       1   1.0       0    1  ...      NaN       NaN     NaN     NaN
# 4       1   1.0       0    1  ...      NaN       NaN     NaN     NaN
# ...   ...   ...     ...  ...  ...      ...       ...     ...     ...
# 8373  552  22.0       1   44  ...      5.0       9.0     5.0     6.0
# 8374  552  22.0       1   44  ...      5.0       9.0     5.0     6.0
# 8375  552  22.0       1   44  ...      5.0       9.0     5.0     6.0
# 8376  552  22.0       1   44  ...      5.0       9.0     5.0     6.0
# 8377  552   NaN       1   44  ...      5.0       9.0     5.0     6.0
#
# [8378 rows x 195 columns]

# %%
dating_data_df=df2[['gender','shopping','gaming','concerts','music']]

# %%
corr_df=dating_data_df.corr()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(dating_data_df.corr())

# %%
plt.figure(figsize=(10,5))
sns.heatmap(dating_data_df.corr(),cmap='coolwarm',annot=True)

# %%
plt.figure(figsize=(10,5))
sns.heatmap(dating_data_df.corr(),annot=True)

# %%
plt.figure(figsize=(5,2.5))
sns.heatmap(dating_data_df.corr(),annot=True)

# %%
sns.jointplot(x='concerts',y='music',data=dating_data_df)

# %%
dating_data_df[(dating_data_df['concerts']==6) & (dating_data_df['music']==8)]
# Out:
#       gender  shopping  gaming  concerts  music
# 130        1       6.0     8.0       6.0    8.0
# 131        1       6.0     8.0       6.0    8.0
# 132        1       6.0     8.0       6.0    8.0
# 133        1       6.0     8.0       6.0    8.0
# 134        1       6.0     8.0       6.0    8.0
# ...      ...       ...     ...       ...    ...
# 7801       0       4.0     5.0       6.0    8.0
# 7802       0       4.0     5.0       6.0    8.0
# 7803       0       4.0     5.0       6.0    8.0
# 7804       0       4.0     5.0       6.0    8.0
# 7805       0       4.0     5.0       6.0    8.0
#
# [329 rows x 5 columns]
